# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Natural Language Processing Project
#
# Welcome to the NLP Project for this section of the course. In this NLP project you will be attempting to classify Yelp Reviews into 1 star or 5 star categories based off the text content in the reviews. This will be a simpler procedure than the lecture, since we will utilize the pipeline methods for more complex tasks.
#
# We will use the [Yelp Review Data Set from Kaggle](https://www.kaggle.com/c/yelp-recsys-2013).
#
# Each observation in this dataset is a review of a particular business by a particular user.
#
# The "stars" column is the number of stars (1 through 5) assigned by the reviewer to the business. (Higher stars is better.) In other words, it is the rating of the business by the person who wrote the review.
#
# The "cool" column is the number of "cool" votes this review received from other Yelp users.
#
# All reviews start with 0 "cool" votes, and there is no limit to how many "cool" votes a review can receive. In other words, it is a rating of the review itself, not a rating of the business.
#
# The "useful" and "funny" columns are similar to the "cool" column.
#
# Let's get started! Just follow the directions below!

# %% [markdown]
# ## Imports
#  **Import the usual suspects. :) **

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
import plotly.offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## The Data
#
# **Read the yelp.csv file and set it as a dataframe called yelp.**

# %%
df = pd.read_csv('yelp.csv')

# %% [markdown]
# ** Check the head, info , and describe methods on yelp.**

# %%
df.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %%
df.describe()
# Out:
#               stars          cool        useful         funny
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300
# std        1.214636      2.067861      2.336647      1.907942
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      1.000000      0.000000
# 75%        5.000000      1.000000      2.000000      1.000000
# max        5.000000     77.000000     76.000000     57.000000

# %%
# Out:
#               stars          cool        useful         funny
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300
# std        1.214636      2.067861      2.336647      1.907942
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      1.000000      0.000000
# 75%        5.000000      1.000000      2.000000      1.000000
# max        5.000000     77.000000     76.000000     57.000000

# %% [markdown]
# **Create a new column called "text length" which is the number of words in the text column.**

# %%
df['length']=df['text'].apply(len)

# %%
df.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny  length
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0     889
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0    1345
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0      76
# 3  uZetl9T0NcROGOyFfughhg     1       2      0     419
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0     469

# %% [markdown]
# # EDA
#
# Let's explore the data
#
# ## Imports
#
# **Import the data visualization libraries if you haven't done so already.**

# %%
print('hello world1')
# Out:
# hello world1

# %% [markdown]
# **Use FacetGrid from the seaborn library to create a grid of 5 histograms of text length based off of the star ratings. Reference the seaborn documentation for hints on this**

# %%
a = sns.FacetGrid(data=df,col='stars')
a.map(plt.hist,'length')

# %% [markdown]
# **Create a boxplot of text length for each star category.**

# %%
df[['stars', 'length']].pivot(columns='stars', values='length').iplot(kind='box')

#sns.boxplot(x='stars',y='length',data=df)
# Out:
# <div>
#
#
#             <div id="86501c2c-63d9-4dbc-94cd-1bc68e99fc6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("86501c2c-63d9-4dbc-94cd-1bc68e99fc6e")) {
#                     Plotly.newPlot(
#                         '86501c2c-63d9-4dbc-94cd-1bc68e99fc6e',
#                         [{"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "name": "1", "orientation": "v", "type": "box", "y": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 594.0, null, null, null, null, null, null, null, 361.0, null, null, null, 1198.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 569.0, null, null, 498.0, 304.0, null, null, null, null, null, 877.0, null, null, null, null, null, null, null, 154.0, null, null, null, null, 2646.0, null, null, null, null, 610.0, 470.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 873.0, null, null, null, null, null, null, null, 1490.0, null, null, null, null, null, 614.0, null, null, null, null, null, null, 1169.0, null, null, null, null, null, null, null, null, null, 203.0, null, null, null, 240.0, null, null, null, null, null, null, null, 206.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 32.0, null, null, null, null, 765.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 395.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 406.0, null, null, null, 801.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 511.0, null, null, null, null, 654.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 1018.0, null, null, null, null, null, 882.0, null, 2188.0, null, null, 193.0, null, null, null, null, null, null, 405.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 740.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 352.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 1255.0, null, null, null, null, null, null, null, 193.0, null, null, null, null, null, null, null, 314.0, null, null, null, null, 2032.0, 90.0, null, null, null, null, null, null, null, null, null, 460.0, null, 525.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 294.0, null, 976.0, null, null, 237.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 199.0, null, null, null, null, null, null, null, null, null, null, 1570.0, null, null, null, 203.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 489.0, 1389.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 3106.0, 323.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 37.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 258.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 1776.0, null, null, null, 184.0, null, null, null, null, null, null, null, null, null, null, null, 750.0, null, null, null, null, null, null, null, null, null, null, null, null, 691.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 71.0, null, null, 47.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, nu ...

# %% [markdown]
# **Create a countplot of the number of occurrences for each type of star rating.**

# %%
sns.countplot(x=df['stars'])

# %% [markdown]
# ** Use groupby to get the mean values of the numerical columns, you should be able to create this dataframe with the operation:**

# %%
stars = df.groupby('stars').mean()
stars
# Out:
#            cool    useful     funny      length
# stars
# 1      0.576769  1.604806  1.056075  826.515354
# 2      0.719525  1.563107  0.875944  842.256742
# 3      0.788501  1.306639  0.694730  758.498289
# 4      0.954623  1.395916  0.670448  712.923142
# 5      0.944261  1.381780  0.608631  624.999101

# %%
# Out:
#            cool    useful     funny  text length
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %% [markdown]
# **Use the corr() method on that groupby dataframe to produce this dataframe:**

# %%
stars.corr()
# Out:
#             cool    useful     funny    length
# cool    1.000000 -0.743329 -0.944939 -0.857664
# useful -0.743329  1.000000  0.894506  0.699881
# funny  -0.944939  0.894506  1.000000  0.843461
# length -0.857664  0.699881  0.843461  1.000000

# %%
# Out:
#                  cool    useful     funny  text length
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text length -0.857664  0.699881  0.843461     1.000000

# %% [markdown]
# **Then use seaborn to create a heatmap based off that .corr() dataframe:**

# %%
plt.figure(figsize=(8,5))
sns.heatmap(stars.corr(),cmap='viridis',annot=True)

# %% [markdown]
# ## NLP Classification Task
#
# Let's move on to the actual task. To make things a little easier, go ahead and only grab reviews that were either 1 star or 5 stars.
#
# **Create a dataframe called yelp_class that contains the columns of yelp dataframe but for only the 1 or 5 star reviews.**

# %%
df.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny  length
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0     889
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0    1345
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0      76
# 3  uZetl9T0NcROGOyFfughhg     1       2      0     419
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0     469

# %%
yelp_class = pd.DataFrame(df[df['stars']==5])
yelp_class=pd.concat([df[df['stars']==1],df[df['stars']==5]],axis=0)
yelp_class = yelp_class.reset_index()
yelp_class
# Out:
#       index             business_id        date               review_id  \
# 0        23  IJ0o6b8bJFAbG6MjGfBebQ  2010-09-05  Dx9sfFU6Zn0GYOckijom-g
# 1        31  vvA3fbps4F9nGlAEYKk_sA  2012-05-04  S9OVpXat8k5YwWCn6FAgXg
# 2        35  o1GIYYZJjM6nM03fQs_uEQ  2011-11-30  ApKbwpYJdnhhgP4NbjQw2Q
# 3        61  l4vBbCL9QbGiwLuLKwD_bA  2011-11-22  DJVxOfj2Rw9zklC9tU3i1w
# 4        64  CEswyP-9SsXRNLR9fFGKKw  2012-05-19  GXj4PNAi095-q9ynPYH3kg
# 5        65  6Ry-gjGqApTSRZkfdYlLmw  2011-05-04  LN4l4wklQB0IVBjm-vq9TA
# 6        71  NNGJQF3WeIHzGzweCpZ-VA  2011-04-23  jNewOjPp56NMDrKlajrgFQ
# 7        79  FkHhy6kWeoJf0xJTqzRWmg  2012-09-17  odua8qFSMEXSFYmElQTspQ
# 8        84  LzpR_jE6VIutJ08s2cdRrw  2009-03-18  EUCqs_gfKZi1YoKVkWjSYw
# 9        89  145SQ_msdQ1yo7J0E63VoA  2011-03-15  VqNdpXrssjJrC0Z_swPUdA
# 10       90  hW0Ne_HTHEAgGF1rAdmR-g  2010-07-06  6iEP6dvHIefVMMnjeDRNcQ
# 11      105  COc06ScpJTN15NXMf4gkqA  2012-06-17  MbLozRSxSjtMJ3YmPCms7Q
# 12      113  1Q_H3BLhKBymF6Se8FfZNw  2009-02-19  _o_WRkKLk7NJeOO6NsOmMA
# 13      119  CvRGjwCsrQs1DYYL3z8R7g  2008-02-27  xCEvHEszA3-CmFqtHacVQg
# 14      126  CgHcO651uEE3aalrkm4boQ  2007-08-22  L8C_ZWqXelQDG_SzAp3TkA
# 15      136  uxoibUaXA-lRXM37ZV8Bsg  2008-12-20  OUhKpg-1LG7bpyxHLtbJDQ
# 16      140  wl51t6lT7leiX64SlkOx6g  2010-10-30  tCps1BXBR4ZUOF-uTxUBMw
# 17      148  zDfaNgSYLn-TwquB5A6AaA  2012-09-14  1xrgXladKl8ukUsiyVU_kA
# 18      165  MUsqPXthMdHoPEow9M3MfA  2007-07-28  EuC1SHR55UGShkq3iovTEQ
# 19      170  u3HMalNH-xBgZUXjnH3O6Q  2010-03-19  Z67Znbe5riZE4YISO45XAA
# 20      190  OOCLVeqqMFfSnKa7liv0Kw  2009-02-10  d4tC0RRd0ldMNZHeIMbGuQ
# 21      208  MwaFQkJxzqg8G5_hTip99A  2012-07-09  dwC-XTgcmFTMKe1q-Cz8vQ
# 22      212  yPJFfglhMHAKciUpjTmgBg  2011-12-27  TkTbb-JkRsdtD5wplSGEtw
# 23      234  q7DzFSkt1ColaWrAOw7rFw  2012-05-27  4FlODbbswl1eq5-z96vppA
# 24      239  s26P-jeVUH9TjnTPQttPag  2012-04-05  -ZjQLlmThaRU5hpgLfmH_Q
# 25      281  8PYmv83XaJTioz5_A-SVxA  2011-08-01  iHw39WDbIi5qgurOkNNiWA
# 26      287  yv9gVqydta-y8NHQQ3XPRw  2012-08-26  D_pEME20C-srxu-D8Se14A
# 27      289  l3yL2rQ6PoFBQ06RLczn9w  2010-08-21  Cluf-ijd2Ubr0hoVjLXoSQ
# 28      292  QIHyWCBG3ftvXbGdHQKdHw  2012-12-29  Dv9iSQe9s_kn5uuhy0iM_w
# 29      299  Lnohr9bpCbHNsomazXDg-w  2008-07-16  IhVNA9hUjtdk1zufzziNug
# ...     ...                     ...         ...                     ...
# 4056   9934  wl51t6lT7leiX64SlkOx6g  2010-08-29  ANoUbOzGBp_OjAD9k-NBvA
# 4057   9937  So1Z7tydx4QqTLSp91Mjug  2011-04-26  fPxUlWm095ETJ84dRYn1-A
# 4058   9939  cdwHgELA2puX2DNfwSt5EA  2012-02-05  rWi4x7gXd3HabS1eJwB0hQ
# 4059   9941  W8WyVVxinyRjzP8gJa7ILg  2009-01-20  lgrfMIvhkCzclg5KEharjw
# 4060   9942  iV7D7fHKb-bF9fCL_bEMtA  2009-04-22  WjkBCWy7pu4U2-3PbvM0bg
# 4061   9943  OY76JYsWn1rhb6Te2BE5Rw  2011-08-19  9IhdGx6Z4OUYXW9oPrPuXQ
# 4062   9945  hfl62LX14YqNpG0g0Tj6_Q  2012-02-27  2hvg6T-sCh7upAe17Jxs3w
# 4063   9947  VsrvWdZL2993olnW3z8R3A  2011-08-20  GW5D1Dv1Uc8X0_-yf0pzPA
# 4064   9951  EGiGWZp_zSqdeftiFQ7MbA  2011-06-13  OvsDIpdK5T4G81NUzWAkTA
# 4065   9956  7tPe20uDErh-iSkfNEWzVQ  2011-01-26  b0NnnjzhDmI7feVNzniZ3w
# 4066   9957  62F17L8z4Q4S7U_TayuDBA  2010-03-13  oTm0bBYcbgoMPJloZUpUwQ
# 4067   9959  uEJQSIjWui-TDWXaGlcqyQ  2010-09-01  -2oWwvRjNEHNDa4TWVlbAA
# 4068   9965  L9UYbtAUOcfTgZFimehlXw  2009-07-31  F9KzEFjAtbWr3h8toNtDgw
# 4069   9966  ttpZx2t4fMAApdU9MFG91w  2012-07-20  rR322HOBSV2JSY6omtNoPw
# 4070   9969  qhIlkXgcC4j34lNTIqu9WA  2011-03-16  qu7tpZFxaPSxiuIgFiiYlQ
# 4071   9970  R6aazv8FB-6BeanY3ag8kw  2009-09-26  gP17ykqduf3AlewSaRb61w
# 4072   9971  JOZqBKIOB8WEBAWm7v1JFA  2008-07-22  QI9rfeWrZnvK5ojz8cEoRg
# 4073   9973  XHr5mXFgobOHoxbPJxmYdg  2009-09-28  udMiWjeG0OGcb4nNddDkBg
# 4074   9975  EWMwV5V9BxNs_U6nNVMeqw  2007-10-20  g4LsVAoafmUDHiS-_yN4tA
# 4075   9977  iDYzGVIF1TDWdjHNgNjCVw  2012-10-30  qaNZyCUJA6Yp0mvPBCknPQ
# 4076   9978  9Y3aQAVITkEJYe5vLZr13w  2010-04-01  ZoTUU6EJ1OBNr7mhqxHBLw
# 4077   9979  GV1P1x9eRb4iZHCxj5_IjA  2012-12-07  eVUs1C4yaVJNrc7SGTAheg
# 4078   9980  GHYOl_cnERMOhkCK_mGAlA  2011-07-03  Q-y3jSqccdytKxAyo1J0Xg
# 4079   9981  AX8lx9wHNYT45lyd7pxaYw  2008-11-27  IyunTh7jnG7v3EYwfF3hPw
# 4080   9989  mQUC-ATrFuMQSaDQb93Pug  2011-10-01  ta2P9joJqeFB8BzFp-AzjA
# 4081   9990  R8VwdLyvsp9iybNqRvm94g  2011-10-03  pcEeHdAJPoFNF23es0kKWg
# 4082   9991  WJ5mq4EiWYAA4Vif0xDfdg  2011-12-05  EuHX-39FR7tyyG1ElvN1Jw
# 4083   9992  f96lWMIAUhYIYy9gOktivQ  2009-03-10  YF17z7HWlMj6aezZc-pVEw
# 4084   9994  L3BSpFvxcNf3T_teitgt6A  2012-03-19  0nxb1gIGFgk3WbC5zwhKZg
# 4085   9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA
#
#       stars                                               text    type  \
# 0         1  U can go there n check the car out. If u wanna...  review
# 1         1  Disgusting!  Had a Groupon so my daughter and ...  review
# 2         1  I've eaten here many times, but none as bad as...  review
# 3         1  I have always been a fan of Burlington's deals...  review
# 4         1  Another night meeting friends here.  I have to...  review
# 5         1  Not busy at all but took nearly 45 min to get ...  review
# 6         1  Yikes, reading other reviews I realize my bad ...  review
# 7         1  This is my first year participating in Arizona...  review
# 8         1  really, I can't believe this place has receive...  review
# 9         1  I was really excited about this event, maybe m...  review
# 10        1  The beach paradise of Ixtapa-Zihuatenejo await...  review
# 11        1  See the huge sign outside that says $2.50? Yea...  review
# 12        1  Unless you are a regular or look like your wal...  review
# 13        1  Take your money elsewhere, unless you've got k...  review
# 14        1  My friend kept telling me how good their lunch...  review
# 15        1  Absolutely horrendous.  This post office will ...  review
# 16        1  Other than the really great happy hour prices,...  review
# 17        1  Been here for many years but have seen a recen...  review
# 18        1                   This place is not there anymore.  review
# 19        1  Rarely do I give a 1 star rating but after fou...  review
# 20        1  What a load of absolutely hideous, uninteresti...  review
# 21        1  Wednesday 7pm.  This place is your average ove...  review
# 22        1  I had not been to an Oregano's in like 10 year...  review
# 23        1  I recently had a shit cleaned at the Intercont...  review
# 24        1  Where are the managers????   It took 1 1/2 hou...  review
# 25        1  Still quite poor both in service and food. may...  review
# 26        1  First, I hope La Fonda management reads these ...  review
# 27        1  I'd say I've been to the Clubhouse a few times...  review
# 28        1  Not that any SBUX is worth going out of your w...  review
# 29        1  How does this restaurant generate so many 4 an...  review
# ...     ...                                                ...     ...
# 4056      5  Love it, love it, love it! I have been eating ...  review
# 4057      5  I know Kerrie through my networking and we ben...  review
# 4058      5  We had brunch at El Chorro today and it was wo...  review
# 4059      5  I have a fond place in my heart for this estab...  review
# 4060      5  Cork is an enigma.\n\nWhat makes it enigmatic ...  review
# 4061      5  Went to Yogurt Kingdom for the first time toni...  review
# 4062      5  I find it hilarious that someone would referen...  review
# 4063      5                                    LOVE Five Guys!  review
# 4064      5  This is a great Mexican food restaurant. I eat...  review
# 4065      5  "So Jimmy, tell the class what you saw at Swee...  review
# 4066      5  Standard Mexican fare - but quite delicious.  ...  review
# 4067      5  My profile says....\n\nMy Last Meal On Earth: ...  review
# 4068      5  Treats: We tried the cookies (chocolate chip a...  review
# 4069      5  I first joined 24 hr fitness about a year ago,...  review
# 4070      5  Leah, the trainer, at Dog House Training Acade...  review
# 4071      5  This place is super cute lunch joint.  I had t...  review
# 4072      5  The staff is great, the food is great, even th...  review
# 4073      5  Wow!  Went on a Sunday around 11am - busy but ...  review
# 4074      5  When I lived in Phoenix, I was a regular at Fe...  review
# 4075      5  Why did I wait so long to try this neighborhoo...  review
# 4076      5  This is the place for a fabulos breakfast!! I ...  review
# 4077      5  Highly recommend. This is my second time here ...  review
# 4078      5  5 stars for the great $5 happy hour specials. ...  review
# 4079      5  We brought the entire family to Giuseppe's las...  review
# 4080      5  Great food and service! Country food at its best!  review
# 4081      5  Yes I do rock the hipster joints.  I dig this ...  review
# 4082      5  Only 4 stars? \n\n(A few notes: The folks that...  review
# 4083      5  I'm not normally one to jump at reviewing a ch...  review
# 4084      5  Let's see...what is there NOT to like about Su...  review
# 4085      5  4-5 locations.. all 4.5 star average.. I think...  review
#
#                      user_id  cool  useful  funny  length
# 0     zRlQEDYd_HKp0VS3hnAffA     0       1      1     594
# 1     8AMn6644NmBf96xGO3w6OA     0       1      0     361
# 2     iwUN95LIaEr75TZE_JC6bg     0       4      3    1198
# 3     EPROVap0M19Y6_4uf3eCmQ     0       0      0     569
# 4     MjLAe48XNfYlTeFYca5gMw     0       1      2     498
# 5     rWN1pg3mCF2btJWtG6JmJA     0       1      0     304
# 6     5je-Jg8tq5BWxJtDBmTK2Q     0       6      1     877
# 7     68exKLCQnnZrvXNFOcIUnA     0       0      0     154
# 8     HY9qpAamqLXFoa7xMwNntg     1       1      3    2646
# 9     ASi6ZgbbwXIwU2H24uANmQ     0       1      0     610
# 10    8tbXmjYGsYFZXk6ppuwRWQ     7       7      9     470
# 11    UfMHoQ4lic1aCkXFa4TxlA     0       2      1     873
# 12    JnRT9i2d71pY8D8ngzCz9Q     0       1      0    1490
# 13    jKeaOrPyJ-dI9SNeVqrbww     0       0      0     614
# 14    QSYnt4piL87oEWJHJ8_pGA     0       1      0    1169
# 15    VKiWDL608wBRQtk05ts59g     0       3      1     203
# 16    WgdgOlb-OIwKxb1p4xWwRA     0       0      0     240
# 17    pRw80rCPUTcBo2Zv5De1yQ     0       0      0     206
# 18    VBEbhE0ISjg6xowGNiGmgQ     0       3      1      32
# 19    QnMPMD8Nh3ErZGfMRGAeYg     0       0      0     765
# 20    17PPxx8RxjOUD_nQZ1aHEw     4       6      7     395
# 21    Pk5T0OFCbl8mIKkKYyglWQ     0       2      1     406
# 22    KucBnMrhalzxnD9AWrxwYQ     2       4      0     801
# 23    JnJDO8c37PnwsP0P7-1v0w     0       0      0     511
# 24    Rv3k5uOZT5i40aLmlhw4DA     0       0      0     654
# 25    Zgp9T6IOVFOozrWDw_mUGQ     0       0      0    1018
# 26    vKs0r5yZhfJYdBSd0J1a3Q     0       0      0     882
# 27    80PHOfM8KOBb7xEQN4C0lg     0       0      0    2188
# 28    QiLOh5KHp81eiju-n-z1Ng     0       0      0     193
# 29    UE1UIi95jSk5tAzOdtnjIA     0       3      0     405
# ...                      ...   ...     ...    ...     ...
# 4056  zLToLBt6Yc1NjDvSphbP7Q     0       1      0     597
# 4057  1gspFi59uDO00PSM5LMlhQ     0       0      0     426
# 4058  Z4xZrZi_AMtOR6I24dPrHQ     0       0      0     377
# 4059  PShy2RYNadDUhJf4ErOJ7w     1       1      3     606
# 4060  l81ILmOhky5bG7o4r3rkhQ     8      12      6    1194
# 4061  haYHbLXLX2cmHq1wQAEtfg     0       0      0     943
# 4062  9g_ARKx0eJmNH8oO1TR9rQ     0       0      1    2619
# 4063  FYdLG8vxUfhqd6v-QQHRkw     0       0      0      15
# 4064  fi5y6-daDzTIQ7wOKaR7xg     0       0      0     309
# 4065  P2kVk4cIWyK4e4h14RhK-Q    14      15     16     786
# 4066  TnTkd3MKoIOKqrsPDzhiog     0       0      0     118
# 4067  EDN_wou8EEkuaj5Pd83cQA     2       2      1     754
# 4068  2lvfBteL5ny4CBjNIk9Mwg     0       0      0     648
# 4069  iPnpD62l5LUL7WXaI3SJFA     0       0      1     962
# 4070  RKxsZo6XkRU-0y1JgqqsBA     1       1      0     938
# 4071  mtoKqaQjGPWEc5YZbrYV9w     0       0      0     432
# 4072  uBAMd01ZtGXaHrRD6THNzg     1       2      1     318
# 4073  yRYNx24kUDRRBfJu1Rcojg     0       0      0     353
# 4074  TLj3XaclA7V4ldJ5yNP-9Q     1       1      0    1015
# 4075  Id-8-NMEKxeXBR44eUdDeA     3       6      3    2918
# 4076  vasHsAZEgLZGJDTlIweUYQ     0       1      0     493
# 4077  bJFdmJJxfXgCYA5DMmyeqQ     2       2      1     244
# 4078  xZvRLPJ1ixhFVomkXSfXAw     6       6      4     393
# 4079  fczQCSmaWF78toLEmb0Zsw    10       9      5     885
# 4080  fKaO8fR1IAcfvZb6cBrs2w     0       1      0      49
# 4081  b92Y3tyWTQQZ5FLifex62Q     1       1      1     263
# 4082  hTau-iNZFwoNsPCaiIUTEA     1       1      0     908
# 4083  W_QXYA7A0IhMrvbckz7eVg     2       3      2    1326
# 4084  OzOZv-Knlw3oz9K5Kh5S6A     1       2      1    1968
# 4085  KSBFytcdjPKZgXKQnYQdkA     0       0      0     461
#
# [4086 rows x 12 columns]

# %% [markdown]
# ** Create two objects X and y. X will be the 'text' column of yelp_class and y will be the 'stars' column of yelp_class. (Your features and target/labels)**

# %%
X = yelp_class['text']
y = yelp_class['stars']

# %% [markdown]
# **Import CountVectorizer and create a CountVectorizer object.**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %% [markdown]
# ** Use the fit_transform method on the CountVectorizer object and pass in X (the 'text' column). Save this result by overwriting X.**

# %%
X=cv.fit_transform(X)

# %%
X
# Out:
# <4086x19183 sparse matrix of type '<class 'numpy.int64'>'
# 	with 317288 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Train Test Split
#
# Let's split our data into training and testing data.
#
# ** Use train_test_split to split up the data into X_train, X_test, y_train, y_test. Use test_size=0.3 and random_state=101 **

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Training a Model
#
# Time to train a model!
#
# ** Import MultinomialNB and create an instance of the estimator and call is nb **

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %% [markdown]
# **Now fit nb using the training data.**

# %%
nb.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Predictions and Evaluations
#
# Time to see how our model did!
#
# **Use the predict method off of nb to predict labels from X_test.**

# %%
pred = nb.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report using these predictions and y_test **

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[159  70]
#  [ 16 981]]
#               precision    recall  f1-score   support
#
#            1       0.91      0.69      0.79       229
#            5       0.93      0.98      0.96       997
#
#    micro avg       0.93      0.93      0.93      1226
#    macro avg       0.92      0.84      0.87      1226
# weighted avg       0.93      0.93      0.93      1226

# %%
# Out:
# [[159  69]
#  [ 22 976]]
#
#
#              precision    recall  f1-score   support
#
#           1       0.88      0.70      0.78       228
#           5       0.93      0.98      0.96       998
#
# avg / total       0.92      0.93      0.92      1226

# %% [markdown]
# **Great! Let's see what happens if we try to include TF-IDF to this process using a pipeline.**

# %% [markdown]
# # Using Text Processing
#
# ** Import TfidfTransformer from sklearn. **

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %% [markdown]
# ** Import Pipeline from sklearn. **

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# ** Now create a pipeline with the following steps:CountVectorizer(), TfidfTransformer(),MultinomialNB()**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer()),
    ('tfidf',TfidfTransformer()),
    ('classifier',RandomForestClassifier())
])

# %% [markdown]
# ## Using the Pipeline
#
# **Time to use the pipeline! Remember this pipeline has all your pre-process steps in it already, meaning we'll need to re-split the original data (Remember that we overwrote X as the CountVectorized version. What we need is just the text**

# %% [markdown]
# ### Train Test Split
#
# **Redo the train test split on the yelp_class object.**

# %%
X=yelp_class['text']
y=yelp_class['stars']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# **Now fit the pipeline to the training data. Remember you can't use the same training data as last time because that data has already been vectorized. We need to pass in just the text and labels**

# %%
pipeline.fit(X_train,y_train)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning:
#
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# Pipeline(memory=None,
#      steps=[('bow', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_...obs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %% [markdown]
# ### Predictions and Evaluation
#
# ** Now use the pipeline to predict from the X_test and create a classification report and confusion matrix. You should notice strange results.**

# %%
p_pred = pipeline.predict(X_test)

# %%
print(confusion_matrix(y_test,p_pred))
print(classification_report(y_test,p_pred))
# Out:
# [[ 79 150]
#  [ 15 982]]
#               precision    recall  f1-score   support
#
#            1       0.84      0.34      0.49       229
#            5       0.87      0.98      0.92       997
#
#    micro avg       0.87      0.87      0.87      1226
#    macro avg       0.85      0.66      0.71      1226
# weighted avg       0.86      0.87      0.84      1226

# %% [markdown]
# Looks like Tf-Idf actually made things worse! That is it for this project. But there is still a lot more you can play with:
#
# **Some other things to try....**
# Try going back and playing around with the pipeline steps and seeing if creating a custom analyzer like we did in the lecture helps (note: it probably won't). Or recreate the pipeline with just the CountVectorizer() and NaiveBayes. Does changing the ML model at the end to another classifier help at all?

# %% [markdown]
# # Great Job!
